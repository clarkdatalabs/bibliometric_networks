# %%
import csv
import networkx as nx
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
DG = nx.DiGraph()

# %%
link_dict = {}

with open('links_by_book_without_commentary.csv', "r") as csvfile:
    reader = csv.reader(csvfile)
    
    next(reader)
    for i in reader:
#         print(i)
#         text_referenced = i[0]
#         referencer = i[1]
#         count = i[2]
        link_dict[i[0]] = ({'text': i[1]}, {'weight':i[2]})
        edgeData= {"weight": i[2]}
        DG.add_edge(i[1],i[0], weight=i[2])
        
        
        
# ['Sefer Mitzvot Gadol', 'Tur', '3510']
# ['Daf Shevui to Ketubot', 'Ketubot', '2827']
# ['Bereishit Rabbah', 'Genesis', '2321']
# ['Sefer Mitzvot Gadol', 'Shulchan Arukh, Choshen Mishpat', '2271']

# %%
layout = nx.spring_layout(DG)
nx.draw_spring(DG)
edgeDataLabels = {}

for a, b in DG.edges():
    # print(DG.get_edge_data(a, b, {"weight":0})["weight"])
    edgeDataLabels[(a, b)] = str(DG.get_edge_data(a, b,["weight"]))
    # retrieve the edge data dictionary

# %%
# nx.draw_networkx(DG,pos=layout, width = .1, alpha = .8) # draw the edge labels
nx.draw_spring(DG, width = .1, node_size=1, alpha = .8, scale = 2) # draw the edge labels

# plt.show()
plt.savefig("graph.pdf")

# %%
# DG.edges(data=True)
# ('Tur', 'Sefer Mitzvot Gadol', {'weight': '3510'}), ('Tur', 'Bava Batra', {'weight': '1556'})

# %%
 # creates an edge from aNode1 to aNode2
for x in link_dict:
    DG.add_edge(link_dict[x][0]["text"], x)

# %%
len(link_dict)
# Out:
# 1443

# %%
layout = nx.spring_layout(DG)

# %%
nx.draw_spring(DG)

# %%
edgeDataLabels = {}

# %%
for a, b in DG.edges():
    print(DG.get_edge_data(a, b, {"weight":0})["weight"])
    edgeLabels[(a, b)] = str(DG.get_edge_data(a, b,["weight"]))
    # retrieve the edge data dictionary
    
nx.draw_networkx_edge_labels(DG,pos=layout, edge_labels=edgeLabels) # draw the edge labels
# plt.show()
plt.savefig("graph.png", dpi=1000)
# show the plotting window
# Out:
# 3510
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-112ca32f59b1> in <module>()
#       1 for a, b in DG.edges():
#       2     print(DG.get_edge_data(a, b, {"weight":0})["weight"])
# ----> 3     edgeLabels[(a, b)] = str(DG.get_edge_data(a, b,["weight"]))
#       4     # retrieve the edge data dictionary
#       5
#
# NameError: name 'edgeLabels' is not defined

# %%
link_dict
# Out:
# {'Sefer Mitzvot Gadol': ({'text': 'Zevachim'}, {'weight': '24'}),
#  'Daf Shevui to Ketubot': ({'text': 'Horayot'}, {'weight': '1'}),
#  'Bereishit Rabbah': ({'text': 'Tosafot on Bava Kamma'}, {'weight': '1'}),
#  'Psalms': ({'text': 'Tzavaat HaRivash'}, {'weight': '1'}),
#  'Genesis': ({'text': 'Mishnah Yoma'}, {'weight': '1'}),
#  'Sifra': ({'text': 'Tosefta Berakhot'}, {'weight': '1'}),
#  'Bava Kamma': ({'text': 'Ramban on Numbers'}, {'weight': '1'}),
#  'Exodus': ({'text': 'Rif Shevuot'}, {'weight': '1'}),
#  'Bava Batra': ({'text': 'Rash MiShantz on Mishnah Terumot'}, {'weight': '1'}),
#  'Bava Metzia': ({'text': 'Yachin on Mishnah Middot'}, {'weight': '1'}),
#  'Midrash Tehillim': ({'text': 'Orchot Tzadikim'}, {'weight': '1'}),
#  'Deuteronomy': ({'text': 'Mekor Mayim Chayim on Baal Shem Tov'},
#   {'weight': '1'}),
#  'Isaiah': ({'text': 'Rambam on Mishnah Maasrot'}, {'weight': '1'}),
#  'Otzar Midrashim': ({'text': 'Tosefta Keritot'}, {'weight': '1'}),
# ...

# %%
# x = ([('Text 1', 'Sefer Mitzvot Gadol'), ('Text 2', 'Tur'), ('Link Count', '3510')])

# %%
mapping_set = set()

# %%
for x in link_dict:
    mapping_set.add(x)
    mapping_set.add(link_dict[x][0]["text"])

# %%
mapping_dict = {}

# %%
counter = 0
for i in mapping_set:
    mapping_dict[i] = counter
    counter += 1
    
#     length = 1463

# %%
# Example
# OrderedDict([('Text 1', 'Sefer Mitzvot Gadol'), ('Text 2', 'Tur'), ('Link Count', '3510')])
# OrderedDict([('Text 1', 'Daf Shevui to Ketubot'), ('Text 2', 'Ketubot'), ('Link Count', '2827')])
# OrderedDict([('Text 1', 'Bereishit Rabbah'), ('Text 2', 'Genesis'), ('Link Count', '2321')])
# OrderedDict([('Text 1', 'Sefer Mitzvot Gadol'), ('Text 2', 'Shulchan Arukh, Choshen Mishpat'), ('Link Count', '2271')])

# %%
nx.draw(DG)
