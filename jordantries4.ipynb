# %%
# !conda env create --file environment.yml
# Out:
# ...
# Solving environment: done
#
# ...
# pyzmq-18.0.1         | 433 KB    | ##################################### | 100%
# pygments-2.3.1       | 641 KB    | ##################################### | 100%
# pywavelets-1.0.2     | 4.3 MB    | ##################################### | 100%
# pykdtree-1.3.1       | 60 KB     | ##################################### | 100%
# libssh2-1.8.0        | 219 KB    | ##################################### | 100%
# freexl-1.0.5         | 42 KB     | ##################################### | 100%
# libxml2-2.9.8        | 1.9 MB    | ##################################### | 100%
# jsonschema-3.0.1     | 85 KB     | ##################################### | 100%
# openssl-1.1.1b       | 3.5 MB    | ##################################### | 100%
# pyqt-5.6.0           | 4.6 MB    | ##################################### | 100%
# snappy-1.1.7         | 40 KB     | ##################################### | 100%
# ...

# %%
# will have to re-run this when re-opening
# !source activate ds

# %%
# !datashader examples
# Out:
# Copied examples to /Users/Jordan_Earnest/Documents/GitHub/bibliometric_networks/datashader-examples
# Fetching data defined in /Users/Jordan_Earnest/Documents/GitHub/bibliometric_networks/datashader-examples/datasets.yml and placing in /Users/Jordan_Earnest/Documents/GitHub/bibliometric_networks/datashader-examples/data
# ...
# [################################] 17074/17074 - 00:00:14
# ...
# [################################] 44160/44160 - 00:00:11
# ...
# [################################] 422160/422160 - 00:00:22
# ...
# [################################] 2021/2021 - 00:00:01
# ...
# [################################] 1214/1214 - 00:00:00
# ...
# [################################] 1332760/1332760 - 00:01:19
# ...
# [################################] 203703/203703 - 00:01:07
# ...
# [################################] 835670/835670 - 00:00:42
# ...
# [################################] 59/59 - 00:00:00
# ...
# [################################] 1649/1649 - 00:00:00
# ...
# [################################] 20444/20444 - 00:00:13
